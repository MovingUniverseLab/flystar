# %% [markdown]
# # Gaia Data for OB150029
#
# Search Gaia DR2

# %%
import numpy as np
import pylab as plt
from astropy.io import fits
from astropy import table
from flystar import starlists, align
from flystar import transforms
from flystar import analysis, plots
from matplotlib.colors import LogNorm
import copy
from importlib import reload

target = 'ob150029'
ra = '17:59:46.60'
dec = '-28:38:41.8'
# Out:
# Created TAP+ (v20200428.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v20200428.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %% [markdown]
# Define the coordinates for this object. We will search within 10" radius of the target.

# %%
search_rad = 10.0   # arcsec

gaia = analysis.query_gaia(ra, dec, search_radius=search_rad)

# Coordinates are arcsecs offset +x to the East.
targets_dict = {'ob150029':   [0.0, 0.0],
                'S11_15_3.9': [ 1.13982, 3.73524],
                'S13_13_4.5': [-4.42878, 0.03100]
               }

my_gaia = analysis.prepare_gaia_for_flystar(gaia, ra, dec, targets_dict=targets_dict)
print(my_gaia)
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Upgrading Table to masked Table. Use Table.filled() to convert to unmasked table. [astropy.table.table]
# Found match for:  ob150029
# Found match for:  S11_15_3.9
# Found match for:  S13_13_4.5
#         name                 x0          ...    parallax_error
#                                          ...         mas
# ------------------- -------------------- ... -------------------
#            ob150029 0.039217438939947676 ... 0.28948272331245556
# 4062575141137611008   1.0566811709841983 ...                  --
# 4062575136877849344    0.585468014265451 ...  0.3168128436771345
# 4062575136877849984   2.0158611670334037 ... 0.31986670363547376
# 4062575141204361984   -0.185364253800593 ...                  --
# 4062575141204360192   1.2268301828887946 ... 0.33477434234796166
#          S11_15_3.9  -1.0880466151592305 ... 0.38347823442402623
#          S13_13_4.5   4.4589828598191374 ...  0.2254779779215836
# 4062575141204355456  -2.9838334721765385 ...  0.4546255080444859
# 4062575136877789568   1.0650752068039915 ...                  --
#                 ...                  ... ...                 ...
# 4062575343013101824    6.340233199836748 ... 0.08989449502286208
# 4062575342998381184    8.626827200169338 ...  0.1345713183953468
# 4062575136877786752   -2.348361346862809 ...                  --
# 4062575141207471872    6.076818731359224 ...                  --
# 4062575141204359936   -7.541349377650929 ... 0.34993858908933384
# 4062575136839951104    8.116064782161171 ... 0.07215715011739125
# 4062575136877878144    -9.11198175456104 ... 0.18185743505641358
# 4062575141137608832   -6.198651343717921 ...  0.3648334899468703
# 4062575141204355200   -9.597611589469278 ...                  --
# 4062575136877895936   -7.263725846168761 ...                  --
# Length = 30 rows
# WARNING: W35: None:42:0: W35: 'value' attribute required for INFO elements [astropy.io.votable.tree]
# WARNING: W35: None:43:0: W35: 'value' attribute required for INFO elements [astropy.io.votable.tree]
# WARNING: W35: None:45:0: W35: 'value' attribute required for INFO elements [astropy.io.votable.tree]
# WARNING: W06: None:85:0: W06: Invalid UCD 'arith.ratio': Secondary word 'arith.ratio' is not valid as a primary word [astropy.io.votable.tree]
# WARNING: W50: None:88:0: W50: Invalid unit string 'mas.yr**-1' [astropy.io.votable.tree]
# WARNING: W50: None:91:0: W50: Invalid unit string 'mas.yr**-1' [astropy.io.votable.tree]
# WARNING: W50: None:94:0: W50: Invalid unit string 'mas.yr**-1' [astropy.io.votable.tree]
# WARNING: W50: None:97:0: W50: Invalid unit string 'mas.yr**-1' [astropy.io.votable.tree]
# WARNING: W50: None:160:0: W50: Invalid unit string 'mas**-2' [astropy.io.votable.tree]
# WARNING: W50: None:163:0: W50: Invalid unit string 'um**-1' [astropy.io.votable.tree]
# WARNING: W06: None:166:0: W06: Invalid UCD 'em.wavenumber;stat.error': Primary word 'stat.error' is not valid as a secondary word [astropy.io.votable.tree]
# WARNING: W50: None:166:0: W50: Invalid unit string 'um**-1' [astropy.io.votable.tree]
# WARNING: W06: None:178:0: W06: Invalid UCD 'pos.errorEllipse;stat.max': Secondary word 'pos.errorEllipse' is not valid as a primary word [astropy.io.votable.tree]
# WARNING: W50: None:193:0: W50: Invalid unit string ''electron'.s**-1' [astropy.io.votable.tree]
# WARNING: W50: None:196:0: W50: Invalid unit string ''electron'.s**-1' [astropy.io.votable.tree]
# WARNING: W06: None:199:0: W06: Invalid UCD 'arith.ratio': Secondary word 'arith.ratio' is not valid as a primary word [astropy.io.votable.tree]
# WARNING: W50: None:208:0: W50: Invalid unit string ''electron'.s**-1' (suppressing further warnings of this type...) [astropy.io.votable.tree]
# WARNING: W06: None:214:0: W06: Invalid UCD 'arith.ratio': Secondary word 'arith.ratio' is not valid as a primary word [astropy.io.votable.tree]
# WARNING: W06: None:229:0: W06: Invalid UCD 'arith.ratio': Secondary word 'arith.ratio' is not valid as a primary word [astropy.io.votable.tree]
# WARNING: W06: None:241:0: W06: Invalid UCD 'phot.color': Unknown word 'phot.color' [astropy.io.votable.tree]
# WARNING: W06: None:244:0: W06: Invalid UCD 'phot.color': Unknown word 'phot.color' [astropy.io.votable.tree]
# WARNING: W06: None:247:0: W06: Invalid UCD 'phot.color': Unknown word 'phot.color' [astropy.io.votable.tree]
# WARNING: W06: None:319:0: W06: Invalid UCD 'phys.size.radius;stat.error': Primary word 'stat.error' is not valid as a secondary word (suppressing further warnings of this type...) [astropy.io.votable.tree]

# %%
plots.plot_gaia(gaia)
plots.plot_pm(my_gaia)

# %%
gaia[0:10]['source_id','pmra','pmdec'].pprint(max_width=1000)
my_gaia[0:10]['source_id','vx','vy','name'].pprint(max_width=1000)
# Out:
#      source_id              pmra               pmdec
# ------------------- ------------------- -------------------
# 4062575141204361856 -1.6123295507625997  -7.335898165122768
# 4062575141137611008                  --                  --
# 4062575136877849344 -1.8027427941448368  -8.569262819927035
# 4062575136877849984  1.0209671338318573  -5.635913809931664
# 4062575141204361984                  --                  --
# 4062575141204360192  -2.984091249458642  -5.112384710071518
# 4062575136877879296  0.6848936156065186  -6.239739142300629
# 4062575136877897472  -6.338948875708079  -7.038373988981698
# 4062575141204355456 -0.5819423703039869 -2.6648314071503005
# 4062575136877789568                  --                  --
#      source_id                vx                     vy                   name
# ------------------- ---------------------- ---------------------- -------------------
# 4062575141204361856  0.0016123295507625996  -0.007335898165122768            ob150029
# 4062575141137611008                    0.0                    0.0 4062575141137611008
# 4062575136877849344  0.0018027427941448369  -0.008569262819927035 4062575136877849344
# 4062575136877849984 -0.0010209671338318573 -0.0056359138099316645 4062575136877849984
# 4062575141204361984                    0.0                    0.0 4062575141204361984
# 4062575141204360192   0.002984091249458642  -0.005112384710071517 4062575141204360192
# 4062575136877879296 -0.0006848936156065187  -0.006239739142300629          S11_15_3.9
# 4062575136877897472   0.006338948875708079  -0.007038373988981698          S13_13_4.5
# 4062575141204355456  0.0005819423703039869 -0.0026648314071503003 4062575141204355456
# 4062575136877789568                    0.0                    0.0 4062575136877789568

# %% [markdown]
# Plot the stars on top of our NIRC2 image. We need to do some coordinate conversions first.

# %%
# Image to plot
img_base = 'mag17jul19_ob150029_kp.fits'
img = fits.getdata(img_base)

# Get NIRC2 starlist
lis_file = img_base.replace('.fits', '_rms_named.lis')
lis_tab = starlists.StarList.from_lis_file(lis_file)

# Find the target and get its pixel coordinates in this image.
tdx = np.where(lis_tab['name'] == target)[0]
coo_targ = np.array([lis_tab['x'][tdx[0]], lis_tab['y'][tdx[0]]])
coo_targ -= 1   # Shift to a 0-based array system

# %%
# Define the axes
scale = 0.00994
x_axis = np.arange(img.shape[0], dtype=float)
y_axis = np.arange(img.shape[1], dtype=float)
x_axis = (x_axis - (coo_targ[0] - 1)) * scale * -1.0
y_axis = (y_axis - (coo_targ[1] - 1)) * scale

vmin = 10
vmax = 1e5
norm = LogNorm(vmin, vmax)
size = 10**(-(my_gaia['m'] - 23) / 3.0)

idx = np.where(my_gaia['m'] < 20)[0]
plt.figure(figsize=(10,8))
plt.imshow(img, cmap='gist_heat_r', norm=norm, extent=[x_axis[0], x_axis[-1], y_axis[0], y_axis[-1]])
sc = plt.scatter(my_gaia['x0'][idx] * -1.0, my_gaia['y0'][idx], c=my_gaia['m'][idx], s=300, linewidth=3)
sc.set_facecolor('none')
plt.colorbar(label='Gaia G (mag)')
plt.xlabel(r'$\Delta \alpha \; \cos \delta$ (mas)')
plt.ylabel(r'$\Delta \delta$ (mas)')
plt.axis('equal')
plt.title(target.upper())

plt.xlim(5.2, -5.2)
plt.ylim(-5.2, 5.2)
# Out:
# (-5.2, 5.2)

# %%
# Gaia Catalog Prepped for Alignment
print('')
print('New Gaia Catalog')
prt_fmt = '{name:20s}  {mag:5.2f}  {ra:7.4f} +/- {ra_err:6.4f}  {dec:7.4f} +/- {dec_err:6.4f}'
prt_fmt += '  {pmra:8.4f} +/- {pmra_err:7.4f}  {pmdec:8.4f} +/- {pmdec_err:7.4f}'
prt_fmt += '{t0:8.3f}  {gname:20s}' 
for ii in range(10):
    print(prt_fmt.format(name=my_gaia['name'][ii], mag=my_gaia['m'][ii], 
                         ra=my_gaia['x0'][ii], ra_err=my_gaia['x0e'][ii], 
                         dec=my_gaia['y0'][ii], dec_err=my_gaia['y0e'][ii],
                         pmra=my_gaia['vx'][ii], pmra_err=my_gaia['vxe'][ii],
                         pmdec=my_gaia['vy'][ii], pmdec_err=my_gaia['vye'][ii],
                         t0=my_gaia['t0'][ii], gname=my_gaia['source_id'][ii]))


print(my_gaia.colnames)

mdx = np.argsort(lis_tab['m'])
print(lis_tab[mdx][0:10])
# Out:
# New Gaia Catalog
# ob150029              16.24   0.0392 +/- 0.0002   0.0518 +/- 0.0002    0.0016 +/-  0.0005   -0.0073 +/-  0.00042015.500  4062575141204361856
# 4062575141137611008   18.23   1.0567 +/- 0.0171   0.2455 +/- 0.0157    0.0000 +/-  0.0000    0.0000 +/-  0.00002015.500  4062575141137611008
# 4062575136877849344   18.58   0.5855 +/- 0.0003  -2.0732 +/- 0.0003    0.0018 +/-  0.0006   -0.0086 +/-  0.00042015.500  4062575136877849344
# 4062575136877849984   18.52   2.0159 +/- 0.0003   1.5400 +/- 0.0003   -0.0010 +/-  0.0006   -0.0056 +/-  0.00052015.500  4062575136877849984
# 4062575141204361984   18.57  -0.1854 +/- 0.0111   3.1985 +/- 0.0109    0.0000 +/-  0.0000    0.0000 +/-  0.00002015.500  4062575141204361984
# 4062575141204360192   18.50   1.2268 +/- 0.0003  -3.6556 +/- 0.0003    0.0030 +/-  0.0006   -0.0051 +/-  0.00042015.500  4062575141204360192
# S11_15_3.9            17.41  -1.0880 +/- 0.0003   3.8121 +/- 0.0003   -0.0007 +/-  0.0007   -0.0062 +/-  0.00052015.500  4062575136877879296
# S13_13_4.5            17.20   4.4590 +/- 0.0002   0.0605 +/- 0.0002    0.0063 +/-  0.0004   -0.0070 +/-  0.00032015.500  4062575136877897472
# 4062575141204355456   18.67  -2.9838 +/- 0.0004  -4.2529 +/- 0.0004    0.0006 +/-  0.0010   -0.0027 +/-  0.00082015.500  4062575141204355456
# 4062575136877789568   19.32   1.0651 +/- 0.0336  -5.2818 +/- 0.0339    0.0000 +/-  0.0000    0.0000 +/-  0.00002015.500  4062575136877789568
# ['name', 'x0', 'y0', 'x0e', 'y0e', 'vx', 'vy', 'vxe', 'vye', 't0', 'source_id', 'm', 'me', 'parallax', 'parallax_error']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-79b04bc6110c> in <module>
#      16 print(my_gaia.colnames)
#      17
# ---> 18 mdx = np.argsort(lis_tab['m'])
#      19 print(lis_tab[mdx][0:10])
#
# NameError: name 'lis_tab' is not defined

# %% [markdown]
# ## Align all NIRC2 images to Gaia
#
# We will attempt to do an alignment with Gaia 1st to get everything onto an "absolute" reference frame. The Gaia sources have known proper motions and parallaxes, so we will use that information in our alignment.

# %%
reload(align)

# Loop through the observations and read them in, in prep for alignment with Gaia
epochs = ['15jun07', '15jul23', '16may24', '16jul14', '17may21', '17jul14', '17jul19', '18aug21', '19apr17']

list_of_starlists = []

for ee in range(len(epochs)):
    lis_file = 'mag' + epochs[ee] + '_ob150029_kp_rms_named.lis'
    lis = starlists.StarList.from_lis_file(lis_file)
    
    list_of_starlists.append(lis)


print(my_gaia)
msc = align.MosaicToRef(my_gaia, list_of_starlists, iters=2,
                        dr_tol=[0.2, 0.1], dm_tol=[1, 1],
                        trans_class=transforms.PolyTransform,
                        trans_args=[{'order': 1}, {'order': 1}], 
                        use_vel=True,
                        use_ref_new=False,
                        update_ref_orig=False, 
                        mag_trans=True,
                        init_guess_mode='name', verbose=True)

msc.fit()

msc.calc_bootstrap_errors()

tab = msc.ref_table
# Out:
#         name                 x0          ...    parallax_error
#                                          ...         mas
# ------------------- -------------------- ... -------------------
#            ob150029 0.039217438939947676 ... 0.28948272331245556
# 4062575141137611008   1.0566811709841983 ...                  --
# 4062575136877849344    0.585468014265451 ...  0.3168128436771345
# 4062575136877849984   2.0158611670334037 ... 0.31986670363547376
# 4062575141204361984   -0.185364253800593 ...                  --
# 4062575141204360192   1.2268301828887946 ... 0.33477434234796166
#          S11_15_3.9  -1.0880466151592305 ... 0.38347823442402623
#          S13_13_4.5   4.4589828598191374 ...  0.2254779779215836
# 4062575141204355456  -2.9838334721765385 ...  0.4546255080444859
# 4062575136877789568   1.0650752068039915 ...                  --
#                 ...                  ... ...                 ...
# 4062575343013101824    6.340233199836748 ... 0.08989449502286208
# 4062575342998381184    8.626827200169338 ...  0.1345713183953468
# 4062575136877786752   -2.348361346862809 ...                  --
# 4062575141207471872    6.076818731359224 ...                  --
# 4062575141204359936   -7.541349377650929 ... 0.34993858908933384
# 4062575136839951104    8.116064782161171 ... 0.07215715011739125
# 4062575136877878144    -9.11198175456104 ... 0.18185743505641358
# 4062575141137608832   -6.198651343717921 ...  0.3648334899468703
# 4062575141204355200   -9.597611589469278 ...                  --
# 4062575136877895936   -7.263725846168761 ...                  --
# Length = 30 rows
# Parameters used for fit:
# -------------------------
#   dr_tol = [0.2, 0.1]
#   dm_tol = [1, 1]
#   outlier_tol = [None, None]
#   trans_args = [{'order': 1}, {'order': 1}]
#   mag_trans = True
#   mag_lim = [[None None]
#  [None None]
#  [None None]
#  [None None]
#  [None None]
#  [None None]
#  [None None]
#  [None None]
#  [None None]]
#   ref_mag_lim = None
#   weights = None
#   n_boot = 0
#   boot_epochs_min = -1
#   trans_input = None
#   trans_class = <class 'flystar.transforms.PolyTransform'>
#   calc_trans_inverse = False
#   use_ref_new = False
#   use_vel = True
#   update_ref_orig = False
#   init_guess_mode = name
#   iter_callback = None
# -------------------------
#
#
# **********
# **********
# Starting iter 0 with ref_table shape: (30, 1)
# **********
# **********
#
#    **********
#    Matching catalog 1 / 9 with 508 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  None
#           mag_lim:  [None None]
#    **********
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-4528bb19f3e4> in <module>
#      24                         init_guess_mode='name', verbose=True)
#      25
# ---> 26 msc.fit()
#      27
#      28 tab = msc.ref_table
#
# ~/code/python/flystar/flystar/align.py in fit(self)
#    1585             self.match_and_transform(self.ref_mag_lim,
#    1586                                      self.dr_tol[nn], self.dm_tol[nn], self.outlier_tol[nn],
# -> 1587                                      self.trans_args[nn])
#    1588
#    1589             # Clean up the reference table
#
# ~/code/python/flystar/flystar/align.py in match_and_transform(self, ref_mag_lim, dr_tol, dm_tol, outlier_tol, trans_args)
#     407                                             mode=self.init_guess_mode,
#     408                                             verbose=self.verbose,
# --> 409                                             mag_trans=self.mag_trans)
#     410
#     411             if self.mag_trans:
#
# ~/code/python/flystar/flystar/align.py in trans_initial_guess(ref_list, star_list, trans_args, mode, ignore_contains, verbose, n_req_match, mag_trans)
#    3507                                                     star_list['name'][idx_s],
#    3508                                                     assume_unique=True,
# -> 3509                                                     return_indices=True)
#    3510
#    3511         x1m = star_list['x'][idx_s][ndx_s]
#
# <__array_function__ internals> in intersect1d(*args, **kwargs)
#
# ~/anaconda3/envs/astroconda2/lib/python3.6/site-packages/numpy/lib/arraysetops.py in intersect1d(ar1, ar2, assume_unique, return_indices)
#     411     aux = np.concatenate((ar1, ar2))
#     412     if return_indices:
# --> 413         aux_sort_indices = np.argsort(aux, kind='mergesort')
#     414         aux = aux[aux_sort_indices]
#     415     else:
#
# <__array_function__ internals> in argsort(*args, **kwargs)
#
# ~/anaconda3/envs/astroconda2/lib/python3.6/site-packages/numpy/core/fromnumeric.py in argsort(a, axis, kind, order)
#    1103
#    1104     """
# -> 1105     return _wrapfunc(a, 'argsort', axis=axis, kind=kind, order=order)
#    1106
#    1107
#
# ~/anaconda3/envs/astroconda2/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      59
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#      63         # A TypeError occurs if the object does have such a method in its
#
# ~/anaconda3/envs/astroconda2/lib/python3.6/site-packages/numpy/ma/core.py in argsort(self, axis, kind, order, endwith, fill_value)
#    5462                 fill_value = maximum_fill_value(self)
#    5463
# -> 5464         filled = self.filled(fill_value)
#    5465         return filled.argsort(axis=axis, kind=kind, order=order)
#    5466
#
# ~/anaconda3/envs/astroconda2/lib/python3.6/site-packages/astropy/table/column.py in filled(self, fill_value)
#    1303         """
#    1304         if fill_value is None:
# -> 1305             fill_value = self.fill_value
#    1306
#    1307         data = super().filled(fill_value)
#
# ~/anaconda3/envs/astroconda2/lib/python3.6/site-packages/astropy/table/column.py in fill_value(self)
#    1253     @property
#    1254     def fill_value(self):
# -> 1255         return self.get_fill_value()  # defer to native ma.MaskedArray method
#    1256
#    1257     @fill_value.setter
#
# ~/anaconda3/envs/astroconda2/lib/python3.6/site-packages/numpy/ma/core.py in fill_value(self)
#    3651
#    3652         """
# -> 3653         if self._fill_value is None:
#    3654             self._fill_value = _check_fill_value(None, self.dtype)
#    3655
#
# AttributeError: 'MaskedColumn' object has no attribute '_fill_value'

# %%
plots.plot_pm_error(tab)

# %%
# Proper motions for the Gaia catalog:
plots.plot_pm(my_gaia)
plt.axis([-10, 10, -10, 10])

# Proper motions for the Gaia sources in the NIRC2 catalog:
plots.plot_pm(tab[0:10])
plt.axis([-10, 10, -10, 10])

# Proper motions for the entire NIRC2 catalog:
plots.plot_pm(tab)
plt.axis([-10, 10, -10, 10])
# Out:
# [-10, 10, -10, 10]

# %%
my_gaia['name','x0','y0','vx','vy'][0:10].pprint(max_width=1000)
tab['name','x0','y0','vx','vy'][0:10].pprint(max_width=1000)
# Out:
#         name                 x0                   y0                   vx                     vy
# ------------------- -------------------- ------------------- ---------------------- ----------------------
#            ob150029 0.039217438939947676 0.05179165957542864  0.0016123295507625996  -0.007335898165122768
# 4062575141137611008   1.0566811709841983 0.24554193880703679                    0.0                    0.0
# 4062575136877849344    0.585468014265451  -2.073177849668184  0.0018027427941448369  -0.008569262819927035
# 4062575136877849984   2.0158611670334037  1.5399939020255715 -0.0010209671338318573 -0.0056359138099316645
# 4062575141204361984   -0.185364253800593   3.198498641546621                    0.0                    0.0
# 4062575141204360192   1.2268301828887946 -3.6555550744523657   0.002984091249458642  -0.005112384710071517
#          S11_15_3.9  -1.0880466151592305  3.8121017403994983 -0.0006848936156065187  -0.006239739142300629
#          S13_13_4.5   4.4589828598191374 0.06051553631323259   0.006338948875708079  -0.007038373988981698
# 4062575141204355456  -2.9838334721765385  -4.252869294975881  0.0005819423703039869 -0.0026648314071503003
# 4062575136877789568   1.0650752068039915  -5.281753965238067                    0.0                    0.0
#         name                 x0                   y0                   vx                     vy
# ------------------- -------------------- ------------------- ---------------------- ----------------------
#            ob150029 0.039217438939947676 0.05179165957542864  0.0016123295507625996  -0.007335898165122768
# 4062575136877849344    0.585468014265451  -2.073177849668184  0.0018027427941448369  -0.008569262819927035
# 4062575136877849984   2.0158611670334037  1.5399939020255715 -0.0010209671338318573 -0.0056359138099316645
# 4062575141204361984   -0.185364253800593   3.198498641546621                    0.0                    0.0
# 4062575141204360192   1.2268301828887946 -3.6555550744523657   0.002984091249458642  -0.005112384710071517
#          S13_13_4.5   4.4589828598191374 0.06051553631323259   0.006338948875708079  -0.007038373988981698
# 4062575141204355456  -2.9838334721765385  -4.252869294975881  0.0005819423703039869 -0.0026648314071503003
# 4062575136877789568   1.0650752068039915  -5.281753965238067                    0.0                    0.0
# 4062575141206005248    4.051601814556239   3.991931459221121   0.007125065890048892  -0.008602564495557033
# 4062575136877648384  -4.1875962043327855   4.609183326695643   0.004592129857775794   -0.01061615130600751

# %%
plots.plot_quiver_residuals_all_epochs(tab, unit='arcsec', scale=60)
# Out:
# Residuals (mean, std): dx =   0.000 +/-   5.806 mas  dy =  -0.000 +/-   9.786 mas for REF stars
# Residuals (mean, std): dx =  -1.088 +/-   2.034 mas  dy =   3.027 +/-   3.406 mas for GOOD stars
# Residuals (mean, std): dx =   3.455 +/-   5.926 mas  dy =  -8.213 +/-   9.884 mas for REF stars
# Residuals (mean, std): dx =   1.222 +/-   1.932 mas  dy =  -3.033 +/-   3.540 mas for GOOD stars
# Residuals (mean, std): dx =   3.328 +/-   4.915 mas  dy =  -7.926 +/-  10.284 mas for REF stars
# Residuals (mean, std): dx =   0.882 +/-   1.783 mas  dy =  -3.656 +/-   3.086 mas for GOOD stars
# Residuals (mean, std): dx =   2.656 +/-   5.366 mas  dy =  -6.132 +/-  10.379 mas for REF stars
# Residuals (mean, std): dx =   0.934 +/-   2.172 mas  dy =  -1.728 +/-   3.241 mas for GOOD stars
# Residuals (mean, std): dx =   2.143 +/-   4.303 mas  dy =  -5.057 +/-  10.219 mas for REF stars
# Residuals (mean, std): dx =   0.441 +/-   2.216 mas  dy =  -1.477 +/-   3.489 mas for GOOD stars
# Residuals (mean, std): dx =   1.536 +/-   4.393 mas  dy =  -3.659 +/-  11.433 mas for REF stars
# Residuals (mean, std): dx =  -0.152 +/-   2.100 mas  dy =   0.338 +/-   3.734 mas for GOOD stars
# Residuals (mean, std): dx =   1.268 +/-   4.085 mas  dy =  -3.005 +/-  10.586 mas for REF stars
# Residuals (mean, std): dx =  -0.176 +/-   2.191 mas  dy =   0.491 +/-   3.094 mas for GOOD stars
# Residuals (mean, std): dx =   1.067 +/-   4.427 mas  dy =  -2.538 +/-  12.149 mas for REF stars
# Residuals (mean, std): dx =  -0.433 +/-   1.838 mas  dy =   0.865 +/-   3.357 mas for GOOD stars
# Residuals (mean, std): dx =   0.591 +/-   4.714 mas  dy =  -1.470 +/-  11.806 mas for REF stars
# Residuals (mean, std): dx =  -0.703 +/-   2.265 mas  dy =   1.046 +/-   3.097 mas for GOOD stars

# %%
ii = 3

plt.errorbar(tab['t'][ii,:], tab['x'][ii,:], yerr=tab['xe'][ii,:], fmt='k.')
plt.plot(tab['t'][ii,:], tab['x0'][ii] + tab['vx'][ii]*(tab['t'][ii, :] - tab['t0'][ii]), 'r--')

# %% [markdown]
# ## Re-match and transform.

# %%
msc2 = align.MosaicToRef(my_gaia, list_of_starlists, iters=3,
                         dr_tol=[0.2, 0.1, 0.05], dm_tol=[1, 1, 0.5],
                         outlier_tol=[5, 3, 3], mag_lim=[1,19],
                         trans_class=transforms.PolyTransform,
                         trans_input=msc.trans_list,
                         trans_args=[{'order': 2}, {'order': 2}, {'order': 3}], use_vel=True,
                         weights='list,std',
                         update_ref_orig=True, use_ref_new=True, mag_trans=True,
                         init_guess_mode='name', verbose=True)

msc2.fit()

tab2 = msc2.ref_table
# Out:
#
# **********
# **********
# Starting iter 0 with ref_table shape: (30, 1)
# **********
# **********
#
#    **********
#    Matching catalog 1 / 9 with 508 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 10 matches
#   Match 1: Found  10  matches out of  136 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 9 of 10
#   Rejected  1  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  9  stars in transformation.
#     Found 0 duplicates out of 10 matches
#   Match 2: After trans, found  10  matches out of  508 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 528 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 528 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00863 +/-  0.00985
#     dm (mean and std) for all stars :  0.07102 +/-  0.36497
#     dr (mean and std) for trans stars:  0.00568 +/-  0.00452
#     dm (mean and std) for trans stars:  0.27772 +/-  0.14296
#
#    **********
#    Matching catalog 2 / 9 with 423 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 133 matches
#   Match 1: Found  133  matches out of  139 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 132 of 133
#   Rejected  1  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  132  stars in transformation.
#     Found 3 duplicates out of 401 matches
#   Match 2: After trans, found  398  matches out of  423 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 553 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 553 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00222 +/-  0.00897
#     dm (mean and std) for all stars :  0.00585 +/-  0.08596
#     dr (mean and std) for trans stars:  0.00085 +/-  0.00083
#     dm (mean and std) for trans stars:  0.04853 +/-  0.04334
#
#    **********
#    Matching catalog 3 / 9 with 362 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 132 matches
#   Match 1: Found  132  matches out of  137 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 130 of 132
#   Rejected  2  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  130  stars in transformation.
#     Found 0 duplicates out of 336 matches
#   Match 2: After trans, found  336  matches out of  362 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 579 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 579 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00967 +/-  0.00964
#     dm (mean and std) for all stars :  0.00912 +/-  0.15353
#     dr (mean and std) for trans stars:      nan +/-      nan
#     dm (mean and std) for trans stars:      nan +/-      nan
#
#    **********
#    Matching catalog 4 / 9 with 382 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [ 1 19]
#    **********
#     Found 1 duplicates out of 128 matches
#   Match 1: Found  127  matches out of  131 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 125 of 127
#   Rejected  2  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  125  stars in transformation.
#     Found 3 duplicates out of 353 matches
#     confused, dropping
#   Match 2: After trans, found  349  matches out of  382 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 612 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 612 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00450 +/-  0.00954
#     dm (mean and std) for all stars : -0.00582 +/-  0.10558
#     dr (mean and std) for trans stars:      nan +/-      nan
#     dm (mean and std) for trans stars:      nan +/-      nan
#
#    **********
#    Matching catalog 5 / 9 with 245 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 128 matches
#   Match 1: Found  128  matches out of  132 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 125 of 128
#   Rejected  3  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  125  stars in transformation.
#     Found 0 duplicates out of 238 matches
#   Match 2: After trans, found  238  matches out of  245 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 619 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 619 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00299 +/-  0.00414
#     dm (mean and std) for all stars : -0.00266 +/-  0.07864
#     dr (mean and std) for trans stars:  0.00173 +/-  0.00165
#     dm (mean and std) for trans stars:  0.04690 +/-  0.04776
#
#    **********
#    Matching catalog 6 / 9 with 212 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 109 matches
#   Match 1: Found  109  matches out of  114 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 104 of 109
#   Rejected  5  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  104  stars in transformation.
#     Found 0 duplicates out of 199 matches
#   Match 2: After trans, found  199  matches out of  212 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 632 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 632 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00346 +/-  0.00958
#     dm (mean and std) for all stars : -0.01617 +/-  0.15462
#     dr (mean and std) for trans stars:  0.00194 +/-  0.00184
#     dm (mean and std) for trans stars:  0.07123 +/-  0.05233
#
#    **********
#    Matching catalog 7 / 9 with 344 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [ 1 19]
#    **********
#     Found 1 duplicates out of 128 matches
#     confused, dropping
#   Match 1: Found  126  matches out of  132 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 124 of 126
#   Rejected  2  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  124  stars in transformation.
#     Found 2 duplicates out of 316 matches
#     confused, dropping
#   Match 2: After trans, found  313  matches out of  344 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 663 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 663 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00366 +/-  0.00952
#     dm (mean and std) for all stars : -0.00252 +/-  0.10975
#     dr (mean and std) for trans stars:  0.00138 +/-  0.00255
#     dm (mean and std) for trans stars:  0.04550 +/-  0.04974
#
#    **********
#    Matching catalog 8 / 9 with 343 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 121 matches
#   Match 1: Found  121  matches out of  125 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 102 of 121
#   Rejected  19  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  102  stars in transformation.
#     Found 0 duplicates out of 315 matches
#   Match 2: After trans, found  315  matches out of  343 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 691 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 691 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00363 +/-  0.00616
#     dm (mean and std) for all stars :  0.01860 +/-  0.11402
#     dr (mean and std) for trans stars:  0.00125 +/-  0.00113
#     dm (mean and std) for trans stars:  0.05908 +/-  0.04629
#
#    **********
#    Matching catalog 9 / 9 with 406 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 123 matches
#   Match 1: Found  123  matches out of  132 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 111 of 123
#   Rejected  12  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  111  stars in transformation.
#     Found 1 duplicates out of 359 matches
#   Match 2: After trans, found  358  matches out of  406 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 739 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 739 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00648 +/-  0.01828
#     dm (mean and std) for all stars : -0.00555 +/-  0.13888
#     dr (mean and std) for trans stars:  0.00162 +/-  0.00183
#     dm (mean and std) for trans stars:  0.09958 +/-  0.06933
#   *** Getting rid of 0 out of 739 junk sources
#
# **********
# **********
# Starting iter 1 with ref_table shape: (739, 9)
# **********
# **********
#
#    **********
#    Matching catalog 1 / 9 with 508 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 133 matches
#   Match 1: Found  133  matches out of  136 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 129 of 133
#   Rejected  4  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  129  stars in transformation.
#     Found 0 duplicates out of 486 matches
#   Match 2: After trans, found  486  matches out of  508 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 761 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 761 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00084 +/-  0.00126
#     dm (mean and std) for all stars :  0.02154 +/-  0.08217
#     dr (mean and std) for trans stars:  0.00034 +/-  0.00035
#     dm (mean and std) for trans stars:  0.05236 +/-  0.04291
#
#    **********
#    Matching catalog 2 / 9 with 423 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 134 matches
#   Match 1: Found  134  matches out of  139 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 129 of 134
#   Rejected  5  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  129  stars in transformation.
#     Found 1 duplicates out of 405 matches
#   Match 2: After trans, found  404  matches out of  423 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 780 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 780 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00195 +/-  0.00339
#     dm (mean and std) for all stars :  0.00222 +/-  0.09018
#     dr (mean and std) for trans stars:  0.00073 +/-  0.00043
#     dm (mean and std) for trans stars:  0.04858 +/-  0.04252
#
#    **********
#    Matching catalog 3 / 9 with 362 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 134 matches
#   Match 1: Found  134  matches out of  137 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 129 of 134
#   Rejected  5  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  129  stars in transformation.
#     Found 0 duplicates out of 351 matches
#   Match 2: After trans, found  351  matches out of  362 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 791 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 791 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00996 +/-  0.00994
#     dm (mean and std) for all stars :  0.00904 +/-  0.15670
#     dr (mean and std) for trans stars:  0.00411 +/-  0.00358
#     dm (mean and std) for trans stars:  0.11453 +/-  0.07883
#
#    **********
#    Matching catalog 4 / 9 with 382 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 130 matches
#   Match 1: Found  130  matches out of  131 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 127 of 130
#   Rejected  3  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  127  stars in transformation.
#     Found 1 duplicates out of 372 matches
#   Match 2: After trans, found  371  matches out of  382 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 802 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 802 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00452 +/-  0.00930
#     dm (mean and std) for all stars : -0.00629 +/-  0.10622
#     dr (mean and std) for trans stars:  0.00110 +/-  0.00083
#     dm (mean and std) for trans stars:  0.04933 +/-  0.04794
#
#    **********
#    Matching catalog 5 / 9 with 245 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 132 matches
#   Match 1: Found  132  matches out of  132 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 130 of 132
#   Rejected  2  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  130  stars in transformation.
#     Found 0 duplicates out of 244 matches
#   Match 2: After trans, found  244  matches out of  245 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 803 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 803 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00304 +/-  0.00413
#     dm (mean and std) for all stars :  0.00016 +/-  0.08246
#     dr (mean and std) for trans stars:      nan +/-      nan
#     dm (mean and std) for trans stars:      nan +/-      nan
#
#    **********
#    Matching catalog 6 / 9 with 212 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 111 matches
#   Match 1: Found  111  matches out of  114 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 105 of 111
#   Rejected  6  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  105  stars in transformation.
#     Found 0 duplicates out of 204 matches
#   Match 2: After trans, found  204  matches out of  212 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 811 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 811 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00270 +/-  0.00236
#     dm (mean and std) for all stars : -0.02413 +/-  0.16424
#     dr (mean and std) for trans stars:  0.00169 +/-  0.00123
#     dm (mean and std) for trans stars:  0.07145 +/-  0.05280
#
#    **********
#    Matching catalog 7 / 9 with 344 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 129 matches
#   Match 1: Found  129  matches out of  132 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 126 of 129
#   Rejected  3  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  126  stars in transformation.
#     Found 0 duplicates out of 335 matches
#   Match 2: After trans, found  335  matches out of  344 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 820 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 820 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00376 +/-  0.00754
#     dm (mean and std) for all stars : -0.00461 +/-  0.11199
#     dr (mean and std) for trans stars:  0.00121 +/-  0.00116
#     dm (mean and std) for trans stars:  0.04571 +/-  0.05009
#
#    **********
#    Matching catalog 8 / 9 with 343 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 123 matches
#   Match 1: Found  123  matches out of  125 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 118 of 123
#   Rejected  5  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  118  stars in transformation.
#     Found 0 duplicates out of 333 matches
#   Match 2: After trans, found  333  matches out of  343 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 830 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 830 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00375 +/-  0.00628
#     dm (mean and std) for all stars : -0.00442 +/-  0.12748
#     dr (mean and std) for trans stars:  0.00125 +/-  0.00097
#     dm (mean and std) for trans stars:  0.07583 +/-  0.06436
#
#    **********
#    Matching catalog 9 / 9 with 406 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 126 matches
#   Match 1: Found  126  matches out of  132 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 121 of 126
#   Rejected  5  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  121  stars in transformation.
#     Found 0 duplicates out of 383 matches
#   Match 2: After trans, found  383  matches out of  406 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 853 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 853 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00472 +/-  0.00818
#     dm (mean and std) for all stars :  0.01278 +/-  0.14042
#     dr (mean and std) for trans stars:  0.00133 +/-  0.00102
#     dm (mean and std) for trans stars:  0.09425 +/-  0.06903
#   *** Getting rid of 233 out of 853 junk sources
#
# **********
# **********
# Starting iter 2 with ref_table shape: (620, 9)
# **********
# **********
#
#    **********
#    Matching catalog 1 / 9 with 508 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 134 matches
#   Match 1: Found  134  matches out of  136 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 129 of 134
#   Rejected  5  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  129  stars in transformation.
#     Found 0 duplicates out of 502 matches
#   Match 2: After trans, found  502  matches out of  508 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 626 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 626 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00092 +/-  0.00142
#     dm (mean and std) for all stars :  0.02518 +/-  0.08933
#     dr (mean and std) for trans stars:  0.00035 +/-  0.00037
#     dm (mean and std) for trans stars:  0.05705 +/-  0.05774
#
#    **********
#    Matching catalog 2 / 9 with 423 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 134 matches
#   Match 1: Found  134  matches out of  139 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 128 of 134
#   Rejected  6  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  128  stars in transformation.
#     Found 0 duplicates out of 404 matches
#   Match 2: After trans, found  404  matches out of  423 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 645 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 645 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00180 +/-  0.00175
#     dm (mean and std) for all stars :  0.00368 +/-  0.08119
#     dr (mean and std) for trans stars:  0.00071 +/-  0.00042
#     dm (mean and std) for trans stars:  0.04864 +/-  0.04260
#
#    **********
#    Matching catalog 3 / 9 with 362 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 135 matches
#   Match 1: Found  135  matches out of  137 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 130 of 135
#   Rejected  5  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  130  stars in transformation.
#     Found 0 duplicates out of 350 matches
#   Match 2: After trans, found  350  matches out of  362 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 657 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 657 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00950 +/-  0.00890
#     dm (mean and std) for all stars :  0.00772 +/-  0.14921
#     dr (mean and std) for trans stars:  0.00402 +/-  0.00388
#     dm (mean and std) for trans stars:  0.11499 +/-  0.07898
#
#    **********
#    Matching catalog 4 / 9 with 382 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 130 matches
#   Match 1: Found  130  matches out of  131 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 124 of 130
#   Rejected  6  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  124  stars in transformation.
#     Found 0 duplicates out of 371 matches
#   Match 2: After trans, found  371  matches out of  382 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 668 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 668 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00370 +/-  0.00572
#     dm (mean and std) for all stars : -0.00552 +/-  0.10370
#     dr (mean and std) for trans stars:  0.00099 +/-  0.00108
#     dm (mean and std) for trans stars:  0.05068 +/-  0.04864
#
#    **********
#    Matching catalog 5 / 9 with 245 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 130 matches
#   Match 1: Found  130  matches out of  132 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 122 of 130
#   Rejected  8  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  122  stars in transformation.
#     Found 0 duplicates out of 244 matches
#   Match 2: After trans, found  244  matches out of  245 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 669 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 669 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00290 +/-  0.00400
#     dm (mean and std) for all stars : -0.00066 +/-  0.08211
#     dr (mean and std) for trans stars:  0.00147 +/-  0.00125
#     dm (mean and std) for trans stars:  0.04530 +/-  0.04435
#
#    **********
#    Matching catalog 6 / 9 with 212 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 111 matches
#   Match 1: Found  111  matches out of  114 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 107 of 111
#   Rejected  4  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  107  stars in transformation.
#     Found 0 duplicates out of 201 matches
#   Match 2: After trans, found  201  matches out of  212 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 680 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 680 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00257 +/-  0.00226
#     dm (mean and std) for all stars :  0.00043 +/-  0.11158
#     dr (mean and std) for trans stars:  0.00168 +/-  0.00160
#     dm (mean and std) for trans stars:  0.07005 +/-  0.05426
#
#    **********
#    Matching catalog 7 / 9 with 344 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 129 matches
#   Match 1: Found  129  matches out of  132 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 123 of 129
#   Rejected  6  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  123  stars in transformation.
#     Found 0 duplicates out of 335 matches
#   Match 2: After trans, found  335  matches out of  344 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 689 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 689 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00311 +/-  0.00393
#     dm (mean and std) for all stars :  0.00116 +/-  0.08651
#     dr (mean and std) for trans stars:  0.00116 +/-  0.00106
#     dm (mean and std) for trans stars:  0.04449 +/-  0.04971
#
#    **********
#    Matching catalog 8 / 9 with 343 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 123 matches
#   Match 1: Found  123  matches out of  125 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 118 of 123
#   Rejected  5  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  118  stars in transformation.
#     Found 0 duplicates out of 331 matches
#   Match 2: After trans, found  331  matches out of  343 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 701 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 701 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00342 +/-  0.00462
#     dm (mean and std) for all stars :  0.00892 +/-  0.11285
#     dr (mean and std) for trans stars:  0.00136 +/-  0.00175
#     dm (mean and std) for trans stars:  0.06765 +/-  0.05420
#
#    **********
#    Matching catalog 9 / 9 with 406 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [ 1 19]
#    **********
#     Found 0 duplicates out of 127 matches
#   Match 1: Found  127  matches out of  132 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 121 of 127
#   Rejected  6  outliers.
#   Rejected  0  with use_in_trans=False.
#   Using  121  stars in transformation.
#     Found 0 duplicates out of 384 matches
#   Match 2: After trans, found  384  matches out of  406 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 723 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 723 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00384 +/-  0.00551
#     dm (mean and std) for all stars :  0.00736 +/-  0.12814
#     dr (mean and std) for trans stars:  0.00112 +/-  0.00112
#     dm (mean and std) for trans stars:  0.09476 +/-  0.06845
#   *** Getting rid of 98 out of 723 junk sources
# **********
# Final Matching
# **********
#     Found 0 duplicates out of 505 matches
# Matched 505 out of 508 stars in list 0
#     Found 0 duplicates out of 420 matches
# Matched 420 out of 423 stars in list 1
#     Found 0 duplicates out of 360 matches
# Matched 360 out of 362 stars in list 2
#     Found 0 duplicates out of 381 matches
# Matched 381 out of 382 stars in list 3
#     Found 0 duplicates out of 245 matches
# Matched 245 out of 245 stars in list 4
#     Found 0 duplicates out of 212 matches
# Matched 212 out of 212 stars in list 5
#     Found 0 duplicates out of 343 matches
# Matched 343 out of 344 stars in list 6
#     Found 0 duplicates out of 343 matches
# Matched 343 out of 343 stars in list 7
#     Found 0 duplicates out of 406 matches
# Matched 406 out of 406 stars in list 8
# Starting startable.fit_velocities for 625 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 625 stars
#
#    Preparing the reference table...
#   *** Getting rid of 21 out of 625 junk sources

# %%
plots.plot_pm_error(tab2)

# %%
plots.plot_pm(my_gaia)
plt.axis([-10, 10, -10, 10])
plots.plot_pm(tab2[0:10])
plt.axis([-10, 10, -10, 10])
plots.plot_pm(tab2)
plt.axis([-10, 10, -10, 10])
# Out:
# [-10, 10, -10, 10]

# %%
plots.plot_quiver_residuals_all_epochs(tab2, scale=15)
# Out:
# Residuals (mean, std): dx =  -0.003 +/-   0.397 mas  dy =   0.038 +/-   0.459 mas for REF stars
# Residuals (mean, std): dx =  -0.011 +/-   1.091 mas  dy =  -0.055 +/-   0.879 mas for GOOD stars
# Residuals (mean, std): dx =  -0.023 +/-   0.404 mas  dy =   0.078 +/-   0.643 mas for REF stars
# Residuals (mean, std): dx =  -0.033 +/-   0.942 mas  dy =   0.080 +/-   0.911 mas for GOOD stars
# Residuals (mean, std): dx =  -0.060 +/-   0.592 mas  dy =  -0.032 +/-   0.597 mas for REF stars
# Residuals (mean, std): dx =   0.025 +/-   1.236 mas  dy =  -0.037 +/-   1.348 mas for GOOD stars
# Residuals (mean, std): dx =   0.038 +/-   0.581 mas  dy =  -0.096 +/-   0.602 mas for REF stars
# Residuals (mean, std): dx =  -0.012 +/-   1.635 mas  dy =  -0.142 +/-   1.880 mas for GOOD stars
# Residuals (mean, std): dx =   0.103 +/-   0.781 mas  dy =   0.004 +/-   1.243 mas for REF stars
# Residuals (mean, std): dx =   0.040 +/-   1.622 mas  dy =   0.137 +/-   2.583 mas for GOOD stars
# Residuals (mean, std): dx =  -0.052 +/-   1.158 mas  dy =  -0.016 +/-   1.855 mas for REF stars
# Residuals (mean, std): dx =  -0.028 +/-   1.446 mas  dy =  -0.261 +/-   2.166 mas for GOOD stars
# Residuals (mean, std): dx =  -0.008 +/-   0.562 mas  dy =   0.083 +/-   0.865 mas for REF stars
# Residuals (mean, std): dx =   0.194 +/-   1.505 mas  dy =  -0.022 +/-   1.413 mas for GOOD stars
# Residuals (mean, std): dx =   0.059 +/-   0.763 mas  dy =  -0.069 +/-   1.158 mas for REF stars
# Residuals (mean, std): dx =   0.141 +/-   1.362 mas  dy =  -0.080 +/-   1.432 mas for GOOD stars
# Residuals (mean, std): dx =  -0.094 +/-   0.648 mas  dy =  -0.146 +/-   0.750 mas for REF stars
# Residuals (mean, std): dx =  -0.269 +/-   1.442 mas  dy =   0.015 +/-   1.402 mas for GOOD stars

# %% [markdown]
# # Analyze Output

# %%
# Trim based on N_epochs
n_epochs_cut = 6
tdx = np.where(tab2['n_detect'] >= n_epochs_cut)[0]
print('Trimming {0:d} out of {1:d} stars in N_epochs < {2:d}'.format(len(tab2) - len(tdx), len(tab2), n_epochs_cut))
tab2_t = tab2[tdx]

# Rename
label_dat_file = 'ob150029_label.dat'
tab2_t_n = analysis.rename_after_flystar(tab2_t, label_dat_file, dr_tol=0.1, dm_tol=0.3)

plots.plot_pm_error(tab2_t_n)
# Out:
# Trimming 284 out of 604 stars in N_epochs < 6
# S13_13_4.5           S13_13_4.5             4.4288   4.4559   0.0310   0.0501  13.4000  17.0438
# ob150029             ob150029              -0.0000   0.0349  -0.0000   0.0518  12.7000  16.1255
# Temporary shift transformations:
#     dm =   3.5346 +/-   0.1092
#     dx =   0.0310 +/-   0.0039
#     dy =   0.0355 +/-   0.0163
#     Found 0 duplicates out of 95 matches
# Renaming 95 out of 320 stars

# %%
plt.close('all')
plots.plot_stars(tab2_t_n, ['ob150029', 'S002_16_0.3', 'S003_16_0.9', 'S005_16_1.1', 'S011_17_1.0', 'S14_15_2.2'])
# Out:
# Creating residuals plots for star(s):
# ['ob150029', 'S002_16_0.3', 'S003_16_0.9', 'S005_16_1.1', 'S011_17_1.0', 'S14_15_2.2']
# 0 ob150029
# Star:         ob150029
# 	X Chi^2 =  6.22 ( 43.55 for  7 dof)
# 	Y Chi^2 =  2.97 ( 20.81 for  7 dof)
# [2015. 2016. 2017. 2018. 2019. 2020.] [2015.0, 2020.0]
# [-0.7063955454480683, 0.7063955454480683]
# 10 S002_16_0.3
# Star:         S002_16_0.3
# 	X Chi^2 =  2.78 ( 19.47 for  7 dof)
# 	Y Chi^2 =  5.52 ( 38.65 for  7 dof)
# [2015. 2016. 2017. 2018. 2019. 2020.] [2015.0, 2020.0]
# [-1.2419356553009553, 1.2419356553009553]
# 11 S003_16_0.9
# Star:         S003_16_0.9
# 	X Chi^2 =  6.12 ( 42.82 for  7 dof)
# 	Y Chi^2 =  3.57 ( 25.02 for  7 dof)
# [2015. 2016. 2017. 2018. 2019. 2020.] [2015.0, 2020.0]
# [-0.6116486069314936, 0.6116486069314936]
# 12 S005_16_1.1
# Star:         S005_16_1.1
# 	X Chi^2 =  4.19 ( 29.36 for  7 dof)
# 	Y Chi^2 =  1.34 (  9.39 for  7 dof)
# [2015. 2016. 2017. 2018. 2019. 2020.] [2015.0, 2020.0]
# [-0.6268289984555978, 0.6268289984555978]
# 23 S011_17_1.0
# Star:         S011_17_1.0
# 	X Chi^2 =  3.73 ( 26.09 for  7 dof)
# 	Y Chi^2 =  8.44 ( 59.08 for  7 dof)
# [2015. 2016. 2017. 2018. 2019. 2020.] [2015.0, 2020.0]
# [-0.7322474812215716, 0.7322474812215716]
# 1 S14_15_2.2
# Star:         S14_15_2.2
# 	X Chi^2 =  4.53 ( 31.71 for  7 dof)
# 	Y Chi^2 = 20.52 (143.66 for  7 dof)
# [2015. 2016. 2017. 2018. 2019. 2020.] [2015.0, 2020.0]
# [-0.7488090600224508, 0.7488090600224508]
# Fubar

# %% [markdown]
# # Pass 3 of FlyStar
#
# Narrow down to just "good stars" for the transf

# %%
# Get a new reference list from the pass 2 alignment.
p3_ref_list = tab2_t_n['name', 't0',
                       'm0', 'm0e', 
                       'x0', 'x0e', 'vx', 'vxe', 
                       'y0', 'y0e', 'vy', 'vye', 
                       'use_in_trans']

# Repair use_in_trans column
p3_ref_list['use_in_trans'] = np.reshape(p3_ref_list['use_in_trans'].data, (len(p3_ref_list)))

# Check out the mean positional errors vs. magnitude and radius.
plots.plot_errors_vs_r_m(p3_ref_list)

# Designate only the "good-fitting" stars as reference stars. 
# First re-set so we don't have any reference stars. 
use = analysis.pick_good_ref_stars(p3_ref_list, r_cut=3.5, m_cut=23, 
                                        p_err_cut=0.0003, pm_err_cut=0.00025, 
                                        name_cut=['ob150029'], reset=True)


p3_ref_list['use_in_trans'] = False
p3_ref_list['use_in_trans'][use] = True

plots.plot_errors_vs_r_m(p3_ref_list[use])


# Inflate the error bars to a floor of 0.1 mas (additive error term)
# on the reference star list. 
new_list_of_starlists = []
for ii in range(len(list_of_starlists)):
    old_list = list_of_starlists[ii]
    new_list = copy.deepcopy(old_list)
    new_list['xe'] = np.hypot(old_list['xe'], 0.015)  # Adding 0.01 pix (0.1 mas) in quadrature.
    new_list['ye'] = np.hypot(old_list['ye'], 0.015)
    new_list_of_starlists.append(new_list)
# Out:
# pick_good_ref_stars: Starting with 320 stars.
# pick_good_ref_stars: Use 113 stars after r<3.50.
# pick_good_ref_stars: Use 60 stars after m<23.00.
# pick_good_ref_stars: Use 56 stars after p_err<0.00030.
# pick_good_ref_stars: Use 55 stars after pm_err<0.00025.
# pick_good_ref_stars: Use 54 stars after name cut.

# %%
msc3 = align.MosaicToRef(p3_ref_list, new_list_of_starlists, iters=4,
                         dr_tol=[0.2, 0.1, 0.05, 0.04], dm_tol=[1, 1, 0.5, 0.5],
                         outlier_tol=[5, 3, 3, 3], mag_lim=None,
                         trans_class=transforms.PolyTransform,
                         trans_input=msc.trans_list,
                         trans_args=[{'order': 1}, {'order': 2}, {'order': 2}, {'order': 2}], 
                         use_vel=True,
                         weights='list,std',
                         update_ref_orig=True, use_ref_new=False, mag_trans=True,
                         init_guess_mode='name', verbose=True)

msc3.fit()

tab3 = msc3.ref_table
# Out:
#
# **********
# **********
# Starting iter 0 with ref_table shape: (320, 1)
# **********
# **********
#
#    **********
#    Matching catalog 1 / 9 with 508 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [None None]
#    **********
#     Found 24 duplicates out of 335 matches
#     confused, dropping
#     confused, dropping
#     confused, dropping
#     confused, dropping
#     confused, dropping
#   Match 1: Found  305  matches out of  508 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 301 of 305
#   Rejected  4  outliers.
#   Rejected  247  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 23 duplicates out of 339 matches
#     confused, dropping
#   Match 2: After trans, found  314  matches out of  508 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 514 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 514 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00798 +/-  0.00564
#     dm (mean and std) for all stars : -0.03226 +/-  0.06620
#     dr (mean and std) for trans stars:  0.00393 +/-  0.00244
#     dm (mean and std) for trans stars:  0.03469 +/-  0.02341
#
#    **********
#    Matching catalog 2 / 9 with 423 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [None None]
#    **********
#     Found 2 duplicates out of 397 matches
#   Match 1: Found  395  matches out of  423 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 394 of 395
#   Rejected  1  outliers.
#   Rejected  340  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 3 duplicates out of 398 matches
#   Match 2: After trans, found  395  matches out of  423 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 542 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 542 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00228 +/-  0.00907
#     dm (mean and std) for all stars :  0.02627 +/-  0.08584
#     dr (mean and std) for trans stars:  0.00070 +/-  0.00053
#     dm (mean and std) for trans stars:  0.03145 +/-  0.02148
#
#    **********
#    Matching catalog 3 / 9 with 362 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [None None]
#    **********
#     Found 1 duplicates out of 336 matches
#     confused, dropping
#   Match 1: Found  334  matches out of  362 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 331 of 334
#   Rejected  3  outliers.
#   Rejected  277  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 332 matches
#   Match 2: After trans, found  332  matches out of  362 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 572 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 572 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.01004 +/-  0.00958
#     dm (mean and std) for all stars : -0.00880 +/-  0.15349
#     dr (mean and std) for trans stars:  0.00369 +/-  0.00418
#     dm (mean and std) for trans stars:  0.07375 +/-  0.03840
#
#    **********
#    Matching catalog 4 / 9 with 382 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [None None]
#    **********
#     Found 4 duplicates out of 348 matches
#     confused, dropping
#     confused, dropping
#   Match 1: Found  342  matches out of  382 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 338 of 342
#   Rejected  4  outliers.
#   Rejected  284  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 3 duplicates out of 353 matches
#   Match 2: After trans, found  350  matches out of  382 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 604 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 604 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00487 +/-  0.00998
#     dm (mean and std) for all stars :  0.00344 +/-  0.10493
#     dr (mean and std) for trans stars:  0.00107 +/-  0.00078
#     dm (mean and std) for trans stars:  0.03123 +/-  0.02696
#
#    **********
#    Matching catalog 5 / 9 with 245 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 235 matches
#   Match 1: Found  235  matches out of  245 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 231 of 235
#   Rejected  4  outliers.
#   Rejected  177  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 237 matches
#   Match 2: After trans, found  237  matches out of  245 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 612 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 612 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00364 +/-  0.00450
#     dm (mean and std) for all stars : -0.00691 +/-  0.07884
#     dr (mean and std) for trans stars:  0.00131 +/-  0.00102
#     dm (mean and std) for trans stars:  0.03642 +/-  0.03466
#
#    **********
#    Matching catalog 6 / 9 with 212 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 193 matches
#   Match 1: Found  193  matches out of  212 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 192 of 193
#   Rejected  1  outliers.
#   Rejected  138  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 199 matches
#   Match 2: After trans, found  199  matches out of  212 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 625 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 625 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00385 +/-  0.00874
#     dm (mean and std) for all stars :  0.03801 +/-  0.15586
#     dr (mean and std) for trans stars:  0.00148 +/-  0.00090
#     dm (mean and std) for trans stars:  0.04644 +/-  0.03291
#
#    **********
#    Matching catalog 7 / 9 with 344 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [None None]
#    **********
#     Found 2 duplicates out of 304 matches
#     confused, dropping
#   Match 1: Found  301  matches out of  344 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 298 of 301
#   Rejected  3  outliers.
#   Rejected  244  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 2 duplicates out of 313 matches
#     confused, dropping
#     confused, dropping
#   Match 2: After trans, found  309  matches out of  344 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 660 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 660 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00367 +/-  0.00957
#     dm (mean and std) for all stars :  0.01819 +/-  0.10841
#     dr (mean and std) for trans stars:  0.00093 +/-  0.00077
#     dm (mean and std) for trans stars:  0.03330 +/-  0.03423
#
#    **********
#    Matching catalog 8 / 9 with 343 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 304 matches
#   Match 1: Found  304  matches out of  343 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 302 of 304
#   Rejected  2  outliers.
#   Rejected  248  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 308 matches
#   Match 2: After trans, found  308  matches out of  343 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 695 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 695 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00377 +/-  0.00645
#     dm (mean and std) for all stars :  0.03030 +/-  0.11623
#     dr (mean and std) for trans stars:  0.00108 +/-  0.00084
#     dm (mean and std) for trans stars:  0.04884 +/-  0.03736
#
#    **********
#    Matching catalog 9 / 9 with 406 stars
#       dr       < 0.200
#       |dm|     < 1.000
#       outlier tol:  5
#           mag_lim:  [None None]
#    **********
#     Found 1 duplicates out of 353 matches
#     confused, dropping
#   Match 1: Found  351  matches out of  406 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 345 of 351
#   Rejected  6  outliers.
#   Rejected  291  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 1 duplicates out of 360 matches
#   Match 2: After trans, found  359  matches out of  406 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 742 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 742 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00728 +/-  0.02145
#     dm (mean and std) for all stars :  0.03583 +/-  0.13815
#     dr (mean and std) for trans stars:  0.00082 +/-  0.00060
#     dm (mean and std) for trans stars:  0.05567 +/-  0.04036
#   *** Getting rid of 0 out of 742 junk sources
#
# **********
# **********
# Starting iter 1 with ref_table shape: (742, 9)
# **********
# **********
#
#    **********
#    Matching catalog 1 / 9 with 508 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 482 matches
#   Match 1: Found  482  matches out of  508 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 475 of 482
#   Rejected  7  outliers.
#   Rejected  421  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 478 matches
#   Match 2: After trans, found  478  matches out of  508 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 772 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 772 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00101 +/-  0.00173
#     dm (mean and std) for all stars : -0.01173 +/-  0.08196
#     dr (mean and std) for trans stars:  0.00036 +/-  0.00047
#     dm (mean and std) for trans stars:  0.03448 +/-  0.02334
#
#    **********
#    Matching catalog 2 / 9 with 423 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 1 duplicates out of 406 matches
#   Match 1: Found  405  matches out of  423 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 402 of 405
#   Rejected  3  outliers.
#   Rejected  348  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 1 duplicates out of 406 matches
#   Match 2: After trans, found  405  matches out of  423 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 790 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 790 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00233 +/-  0.00350
#     dm (mean and std) for all stars :  0.02500 +/-  0.09010
#     dr (mean and std) for trans stars:  0.00069 +/-  0.00052
#     dm (mean and std) for trans stars:  0.03145 +/-  0.02148
#
#    **********
#    Matching catalog 3 / 9 with 362 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 352 matches
#   Match 1: Found  352  matches out of  362 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 338 of 352
#   Rejected  14  outliers.
#   Rejected  284  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 350 matches
#   Match 2: After trans, found  350  matches out of  362 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 802 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 802 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.01154 +/-  0.01020
#     dm (mean and std) for all stars : -0.01134 +/-  0.15624
#     dr (mean and std) for trans stars:  0.00370 +/-  0.00421
#     dm (mean and std) for trans stars:  0.07375 +/-  0.03840
#
#    **********
#    Matching catalog 4 / 9 with 382 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 1 duplicates out of 368 matches
#   Match 1: Found  367  matches out of  382 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 354 of 367
#   Rejected  13  outliers.
#   Rejected  300  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 371 matches
#   Match 2: After trans, found  371  matches out of  382 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 813 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 813 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00497 +/-  0.00996
#     dm (mean and std) for all stars :  0.00427 +/-  0.10641
#     dr (mean and std) for trans stars:  0.00098 +/-  0.00084
#     dm (mean and std) for trans stars:  0.03123 +/-  0.02696
#
#    **********
#    Matching catalog 5 / 9 with 245 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 242 matches
#   Match 1: Found  242  matches out of  245 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 226 of 242
#   Rejected  16  outliers.
#   Rejected  172  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 243 matches
#   Match 2: After trans, found  243  matches out of  245 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 815 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 815 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00343 +/-  0.00413
#     dm (mean and std) for all stars : -0.00608 +/-  0.08269
#     dr (mean and std) for trans stars:  0.00120 +/-  0.00104
#     dm (mean and std) for trans stars:  0.03642 +/-  0.03466
#
#    **********
#    Matching catalog 6 / 9 with 212 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 203 matches
#   Match 1: Found  203  matches out of  212 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 191 of 203
#   Rejected  12  outliers.
#   Rejected  137  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 204 matches
#   Match 2: After trans, found  204  matches out of  212 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 823 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 823 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00355 +/-  0.00302
#     dm (mean and std) for all stars :  0.03456 +/-  0.16580
#     dr (mean and std) for trans stars:  0.00122 +/-  0.00089
#     dm (mean and std) for trans stars:  0.04644 +/-  0.03291
#
#    **********
#    Matching catalog 7 / 9 with 344 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 331 matches
#   Match 1: Found  331  matches out of  344 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 313 of 331
#   Rejected  18  outliers.
#   Rejected  259  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 333 matches
#   Match 2: After trans, found  333  matches out of  344 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 834 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 834 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00380 +/-  0.00627
#     dm (mean and std) for all stars :  0.01833 +/-  0.10013
#     dr (mean and std) for trans stars:  0.00087 +/-  0.00074
#     dm (mean and std) for trans stars:  0.03330 +/-  0.03423
#
#    **********
#    Matching catalog 8 / 9 with 343 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 317 matches
#   Match 1: Found  317  matches out of  343 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 295 of 317
#   Rejected  22  outliers.
#   Rejected  241  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 330 matches
#   Match 2: After trans, found  330  matches out of  343 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 847 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 847 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00424 +/-  0.00639
#     dm (mean and std) for all stars :  0.02818 +/-  0.12568
#     dr (mean and std) for trans stars:  0.00103 +/-  0.00085
#     dm (mean and std) for trans stars:  0.04884 +/-  0.03736
#
#    **********
#    Matching catalog 9 / 9 with 406 stars
#       dr       < 0.100
#       |dm|     < 1.000
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 1 duplicates out of 363 matches
#   Match 1: Found  362  matches out of  406 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 337 of 362
#   Rejected  25  outliers.
#   Rejected  283  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 386 matches
#   Match 2: After trans, found  386  matches out of  406 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 867 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 867 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00558 +/-  0.00987
#     dm (mean and std) for all stars :  0.04297 +/-  0.13914
#     dr (mean and std) for trans stars:  0.00076 +/-  0.00060
#     dm (mean and std) for trans stars:  0.05567 +/-  0.04036
#   *** Getting rid of 238 out of 867 junk sources
#
# **********
# **********
# Starting iter 2 with ref_table shape: (629, 9)
# **********
# **********
#
#    **********
#    Matching catalog 1 / 9 with 508 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 503 matches
#   Match 1: Found  503  matches out of  508 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 493 of 503
#   Rejected  10  outliers.
#   Rejected  439  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 503 matches
#   Match 2: After trans, found  503  matches out of  508 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 634 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 634 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00102 +/-  0.00157
#     dm (mean and std) for all stars : -0.01173 +/-  0.08627
#     dr (mean and std) for trans stars:  0.00036 +/-  0.00049
#     dm (mean and std) for trans stars:  0.03448 +/-  0.02334
#
#    **********
#    Matching catalog 2 / 9 with 423 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 404 matches
#   Match 1: Found  404  matches out of  423 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 384 of 404
#   Rejected  20  outliers.
#   Rejected  330  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 404 matches
#   Match 2: After trans, found  404  matches out of  423 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 653 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 653 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00219 +/-  0.00197
#     dm (mean and std) for all stars :  0.02695 +/-  0.08119
#     dr (mean and std) for trans stars:  0.00069 +/-  0.00052
#     dm (mean and std) for trans stars:  0.03145 +/-  0.02148
#
#    **********
#    Matching catalog 3 / 9 with 362 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 349 matches
#   Match 1: Found  349  matches out of  362 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 323 of 349
#   Rejected  26  outliers.
#   Rejected  269  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 349 matches
#   Match 2: After trans, found  349  matches out of  362 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 666 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 666 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.01085 +/-  0.00869
#     dm (mean and std) for all stars : -0.00974 +/-  0.14844
#     dr (mean and std) for trans stars:  0.00370 +/-  0.00421
#     dm (mean and std) for trans stars:  0.07375 +/-  0.03840
#
#    **********
#    Matching catalog 4 / 9 with 382 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 370 matches
#   Match 1: Found  370  matches out of  382 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 355 of 370
#   Rejected  15  outliers.
#   Rejected  301  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 370 matches
#   Match 2: After trans, found  370  matches out of  382 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 678 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 678 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00412 +/-  0.00634
#     dm (mean and std) for all stars :  0.00722 +/-  0.10038
#     dr (mean and std) for trans stars:  0.00098 +/-  0.00084
#     dm (mean and std) for trans stars:  0.03123 +/-  0.02696
#
#    **********
#    Matching catalog 5 / 9 with 245 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 245 matches
#   Match 1: Found  245  matches out of  245 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 240 of 245
#   Rejected  5  outliers.
#   Rejected  186  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 245 matches
#   Match 2: After trans, found  245  matches out of  245 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 678 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 678 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00343 +/-  0.00412
#     dm (mean and std) for all stars : -0.00729 +/-  0.08345
#     dr (mean and std) for trans stars:  0.00120 +/-  0.00104
#     dm (mean and std) for trans stars:  0.03642 +/-  0.03466
#
#    **********
#    Matching catalog 6 / 9 with 212 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 202 matches
#   Match 1: Found  202  matches out of  212 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 191 of 202
#   Rejected  11  outliers.
#   Rejected  137  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 202 matches
#   Match 2: After trans, found  202  matches out of  212 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 688 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 688 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00350 +/-  0.00303
#     dm (mean and std) for all stars :  0.05124 +/-  0.11667
#     dr (mean and std) for trans stars:  0.00122 +/-  0.00089
#     dm (mean and std) for trans stars:  0.04644 +/-  0.03291
#
#    **********
#    Matching catalog 7 / 9 with 344 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 335 matches
#   Match 1: Found  335  matches out of  344 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 322 of 335
#   Rejected  13  outliers.
#   Rejected  268  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 335 matches
#   Match 2: After trans, found  335  matches out of  344 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 697 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 697 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00356 +/-  0.00450
#     dm (mean and std) for all stars :  0.01437 +/-  0.08470
#     dr (mean and std) for trans stars:  0.00087 +/-  0.00074
#     dm (mean and std) for trans stars:  0.03330 +/-  0.03423
#
#    **********
#    Matching catalog 8 / 9 with 343 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 334 matches
#   Match 1: Found  334  matches out of  343 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 324 of 334
#   Rejected  10  outliers.
#   Rejected  270  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 333 matches
#   Match 2: After trans, found  333  matches out of  343 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 707 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 707 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00405 +/-  0.00500
#     dm (mean and std) for all stars :  0.02718 +/-  0.11552
#     dr (mean and std) for trans stars:  0.00103 +/-  0.00085
#     dm (mean and std) for trans stars:  0.04884 +/-  0.03736
#
#    **********
#    Matching catalog 9 / 9 with 406 stars
#       dr       < 0.050
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 383 matches
#   Match 1: Found  383  matches out of  406 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 366 of 383
#   Rejected  17  outliers.
#   Rejected  312  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 383 matches
#   Match 2: After trans, found  383  matches out of  406 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 730 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 730 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00454 +/-  0.00617
#     dm (mean and std) for all stars :  0.03827 +/-  0.12760
#     dr (mean and std) for trans stars:  0.00076 +/-  0.00060
#     dm (mean and std) for trans stars:  0.05567 +/-  0.04036
#   *** Getting rid of 99 out of 730 junk sources
#
# **********
# **********
# Starting iter 3 with ref_table shape: (631, 9)
# **********
# **********
#
#    **********
#    Matching catalog 1 / 9 with 508 stars
#       dr       < 0.040
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 505 matches
#   Match 1: Found  505  matches out of  508 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 491 of 505
#   Rejected  14  outliers.
#   Rejected  437  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 505 matches
#   Match 2: After trans, found  505  matches out of  508 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 634 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 634 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00091 +/-  0.00123
#     dm (mean and std) for all stars : -0.01477 +/-  0.07586
#     dr (mean and std) for trans stars:  0.00036 +/-  0.00049
#     dm (mean and std) for trans stars:  0.03448 +/-  0.02334
#
#    **********
#    Matching catalog 2 / 9 with 423 stars
#       dr       < 0.040
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 404 matches
#   Match 1: Found  404  matches out of  423 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 384 of 404
#   Rejected  20  outliers.
#   Rejected  330  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 404 matches
#   Match 2: After trans, found  404  matches out of  423 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 653 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 653 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00219 +/-  0.00197
#     dm (mean and std) for all stars :  0.02695 +/-  0.08119
#     dr (mean and std) for trans stars:  0.00069 +/-  0.00052
#     dm (mean and std) for trans stars:  0.03145 +/-  0.02148
#
#    **********
#    Matching catalog 3 / 9 with 362 stars
#       dr       < 0.040
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 347 matches
#   Match 1: Found  347  matches out of  362 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 322 of 347
#   Rejected  25  outliers.
#   Rejected  268  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 347 matches
#   Match 2: After trans, found  347  matches out of  362 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 668 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 668 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.01066 +/-  0.00835
#     dm (mean and std) for all stars : -0.00996 +/-  0.14881
#     dr (mean and std) for trans stars:  0.00370 +/-  0.00421
#     dm (mean and std) for trans stars:  0.07375 +/-  0.03840
#
#    **********
#    Matching catalog 4 / 9 with 382 stars
#       dr       < 0.040
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 368 matches
#   Match 1: Found  368  matches out of  382 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 351 of 368
#   Rejected  17  outliers.
#   Rejected  297  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 368 matches
#   Match 2: After trans, found  368  matches out of  382 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 682 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 682 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00390 +/-  0.00557
#     dm (mean and std) for all stars :  0.00739 +/-  0.10042
#     dr (mean and std) for trans stars:  0.00098 +/-  0.00084
#     dm (mean and std) for trans stars:  0.03123 +/-  0.02696
#
#    **********
#    Matching catalog 5 / 9 with 245 stars
#       dr       < 0.040
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 243 matches
#   Match 1: Found  243  matches out of  245 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 232 of 243
#   Rejected  11  outliers.
#   Rejected  178  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 243 matches
#   Match 2: After trans, found  243  matches out of  245 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 684 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 684 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00326 +/-  0.00314
#     dm (mean and std) for all stars : -0.00633 +/-  0.08163
#     dr (mean and std) for trans stars:  0.00120 +/-  0.00104
#     dm (mean and std) for trans stars:  0.03642 +/-  0.03466
#
#    **********
#    Matching catalog 6 / 9 with 212 stars
#       dr       < 0.040
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 202 matches
#   Match 1: Found  202  matches out of  212 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 191 of 202
#   Rejected  11  outliers.
#   Rejected  137  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 202 matches
#   Match 2: After trans, found  202  matches out of  212 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 694 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 694 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00350 +/-  0.00303
#     dm (mean and std) for all stars :  0.05124 +/-  0.11667
#     dr (mean and std) for trans stars:  0.00122 +/-  0.00089
#     dm (mean and std) for trans stars:  0.04644 +/-  0.03291
#
#    **********
#    Matching catalog 7 / 9 with 344 stars
#       dr       < 0.040
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 333 matches
#   Match 1: Found  333  matches out of  344 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 320 of 333
#   Rejected  13  outliers.
#   Rejected  266  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 333 matches
#   Match 2: After trans, found  333  matches out of  344 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 705 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 705 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00357 +/-  0.00452
#     dm (mean and std) for all stars :  0.01451 +/-  0.08550
#     dr (mean and std) for trans stars:  0.00087 +/-  0.00074
#     dm (mean and std) for trans stars:  0.03330 +/-  0.03423
#
#    **********
#    Matching catalog 8 / 9 with 343 stars
#       dr       < 0.040
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 332 matches
#   Match 1: Found  332  matches out of  343 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 322 of 332
#   Rejected  10  outliers.
#   Rejected  268  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 331 matches
#   Match 2: After trans, found  331  matches out of  343 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 717 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 717 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00394 +/-  0.00452
#     dm (mean and std) for all stars :  0.02573 +/-  0.11491
#     dr (mean and std) for trans stars:  0.00103 +/-  0.00085
#     dm (mean and std) for trans stars:  0.04884 +/-  0.03736
#
#    **********
#    Matching catalog 9 / 9 with 406 stars
#       dr       < 0.040
#       |dm|     < 0.500
#       outlier tol:  3
#           mag_lim:  [None None]
#    **********
#     Found 0 duplicates out of 381 matches
#   Match 1: Found  381  matches out of  406 . If match count is low, check dr_tol, dm_tol.
#   Outlier Rejection: Keeping 362 of 381
#   Rejected  19  outliers.
#   Rejected  308  with use_in_trans=False.
#   Using  54  stars in transformation.
#     Found 0 duplicates out of 381 matches
#   Match 2: After trans, found  381  matches out of  406 . If match count is low, check dr_tol, dm_tol.
# Starting startable.fit_velocities for 742 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 742 stars
#   Residuals:
#     dr (mean and std) for all stars :  0.00447 +/-  0.00589
#     dm (mean and std) for all stars :  0.03750 +/-  0.12773
#     dr (mean and std) for trans stars:  0.00076 +/-  0.00060
#     dm (mean and std) for trans stars:  0.05567 +/-  0.04036
#   *** Getting rid of 99 out of 742 junk sources
# **********
# Final Matching
# **********
#     Found 0 duplicates out of 505 matches
# Matched 505 out of 508 stars in list 0
#     Found 0 duplicates out of 421 matches
# Matched 421 out of 423 stars in list 1
#     Found 0 duplicates out of 359 matches
# Matched 359 out of 362 stars in list 2
#     Found 0 duplicates out of 380 matches
# Matched 380 out of 382 stars in list 3
#     Found 0 duplicates out of 244 matches
# Matched 244 out of 245 stars in list 4
#     Found 0 duplicates out of 211 matches
# Matched 211 out of 212 stars in list 5
#     Found 0 duplicates out of 344 matches
# Matched 344 out of 344 stars in list 6
#     Found 0 duplicates out of 343 matches
# Matched 343 out of 343 stars in list 7
#     Found 0 duplicates out of 406 matches
# Matched 406 out of 406 stars in list 8
# Starting startable.fit_velocities for 643 stars with n=0 bootstrap
# startable.fit_velocities runtime = 0 s for 643 stars
#
#    Preparing the reference table...
#   *** Getting rid of 28 out of 643 junk sources

# %%
plots.plot_quiver_residuals_all_epochs(tab3, unit='arcsec', scale=10)
# Out:
# Residuals (mean, std): dx =   0.064 +/-   0.504 mas  dy =   0.056 +/-   0.348 mas for REF stars
# Residuals (mean, std): dx =  -0.105 +/-   1.146 mas  dy =   0.192 +/-   1.015 mas for GOOD stars
# Residuals (mean, std): dx =  -0.017 +/-   0.220 mas  dy =   0.053 +/-   0.667 mas for REF stars
# Residuals (mean, std): dx =   0.133 +/-   0.966 mas  dy =   0.242 +/-   1.031 mas for GOOD stars
# Residuals (mean, std): dx =  -0.108 +/-   0.568 mas  dy =   0.106 +/-   0.518 mas for REF stars
# Residuals (mean, std): dx =   0.005 +/-   1.212 mas  dy =  -0.589 +/-   1.579 mas for GOOD stars
# Residuals (mean, std): dx =   0.012 +/-   0.467 mas  dy =  -0.002 +/-   0.511 mas for REF stars
# Residuals (mean, std): dx =   0.025 +/-   1.607 mas  dy =  -0.503 +/-   1.602 mas for GOOD stars
# Residuals (mean, std): dx =  -0.079 +/-   0.746 mas  dy =  -0.175 +/-   0.937 mas for REF stars
# Residuals (mean, std): dx =  -0.003 +/-   1.631 mas  dy =  -0.523 +/-   2.786 mas for GOOD stars
# Residuals (mean, std): dx =  -0.108 +/-   0.924 mas  dy =  -0.102 +/-   0.966 mas for REF stars
# Residuals (mean, std): dx =  -0.214 +/-   1.802 mas  dy =   0.064 +/-   2.445 mas for GOOD stars
# Residuals (mean, std): dx =   0.058 +/-   0.363 mas  dy =   0.025 +/-   0.661 mas for REF stars
# Residuals (mean, std): dx =   0.212 +/-   1.474 mas  dy =   0.003 +/-   1.562 mas for GOOD stars
# Residuals (mean, std): dx =   0.055 +/-   0.768 mas  dy =  -0.043 +/-   0.505 mas for REF stars
# Residuals (mean, std): dx =   0.165 +/-   1.638 mas  dy =   0.313 +/-   1.689 mas for GOOD stars
# Residuals (mean, std): dx =   0.012 +/-   0.311 mas  dy =  -0.011 +/-   0.305 mas for REF stars
# Residuals (mean, std): dx =  -0.138 +/-   1.710 mas  dy =   0.047 +/-   1.530 mas for GOOD stars

# %%
# Trim based on N_epochs
n_epochs_cut = 6
tdx = np.where(tab3['n_detect'] >= n_epochs_cut)[0]
print('Trimming {0:d} out of {1:d} stars in N_epochs < {2:d}'.format(len(tab3) - len(tdx), len(tab3), n_epochs_cut))
tab3_t = tab3[tdx]

rdx = np.where(np.hypot(tab3_t['x0'], tab3_t['y0']) < 3.5)[0]
plots.plot_pm_error(tab3_t[rdx])
# Out:
# Trimming 297 out of 615 stars in N_epochs < 6

# %%
plt.close('all')
plots.plot_stars(tab3_t, ['ob150029', 'S002_16_0.3', 'S003_16_0.9', 'S005_16_1.1', 'S011_17_1.0', 'S14_15_2.2'])
# Out:
# Creating residuals plots for star(s):
# ['ob150029', 'S002_16_0.3', 'S003_16_0.9', 'S005_16_1.1', 'S011_17_1.0', 'S14_15_2.2']
# 0 ob150029
# Star:         ob150029
# 	X Chi^2 =  0.85 (  5.97 for  7 dof)
# 	Y Chi^2 =  0.58 (  4.07 for  7 dof)
# [2015. 2016. 2017. 2018. 2019. 2020.] [2015.0, 2020.0]
# [-0.5473135889337478, 0.5473135889337478]
# 10 S002_16_0.3
# Star:         S002_16_0.3
# 	X Chi^2 =  0.72 (  5.05 for  7 dof)
# 	Y Chi^2 =  1.02 (  7.15 for  7 dof)
# [2015. 2016. 2017. 2018. 2019. 2020.] [2015.0, 2020.0]
# [-1.0443276082131945, 1.0443276082131945]
# 11 S003_16_0.9
# Star:         S003_16_0.9
# 	X Chi^2 =  2.28 ( 15.99 for  7 dof)
# 	Y Chi^2 =  0.35 (  2.46 for  7 dof)
# [2015. 2016. 2017. 2018. 2019. 2020.] [2015.0, 2020.0]
# [-0.5475484794955408, 0.5475484794955408]
# 12 S005_16_1.1
# Star:         S005_16_1.1
# 	X Chi^2 =  1.70 ( 11.93 for  7 dof)
# 	Y Chi^2 =  0.77 (  5.36 for  7 dof)
# [2015. 2016. 2017. 2018. 2019. 2020.] [2015.0, 2020.0]
# [-0.5742242803386667, 0.5742242803386667]
# 23 S011_17_1.0
# Star:         S011_17_1.0
# 	X Chi^2 =  2.00 ( 14.01 for  7 dof)
# 	Y Chi^2 =  1.80 ( 12.62 for  7 dof)
# [2015. 2016. 2017. 2018. 2019. 2020.] [2015.0, 2020.0]
# [-0.5624940343644979, 0.5624940343644979]
# 1 S14_15_2.2
# Star:         S14_15_2.2
# 	X Chi^2 =  1.95 ( 13.62 for  7 dof)
# 	Y Chi^2 =  2.15 ( 15.03 for  7 dof)
# [2015. 2016. 2017. 2018. 2019. 2020.] [2015.0, 2020.0]
# [-0.6194021065993814, 0.6194021065993814]
# Fubar
